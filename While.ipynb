# %%
i=1
while i<6:
    print(i)
    if i==3:
        break
    i+=1
# Out:
# 1
# 2
# 3

# %%
i=1
while i<6:
    print(i)
    i+=1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
a=['fizz','buzz','baz']
while a:
    print(a.pop(-1))
# Out:
# baz
# buzz
# fizz

# %%
i=10
while i<20:
    print(i)
    if i==-70:
        break
    i-=20
# Out:
# 10
# -10
# -30
# -50
# -70

# %%
x=8
while i<=10:
    print('x is currently:',x)
    print('x is still less than x')
    x+=1
# Out:
# x is currently: 8
# x is still less than x
# x is currently: 9
# x is still less than x
# x is currently: 10
# x is still less than x
# x is currently: 11
# x is still less than x
# x is currently: 12
# x is still less than x
# x is currently: 13
# x is still less than x
# x is currently: 14
# x is still less than x
# x is currently: 15
# x is still less than x
# x is currently: 16
# x is still less than x
# x is currently: 17
# x is still less than x
# x is currently: 18
# x is still less than x
# x is currently: 19
# x is still less than x
# x is currently: 20
# x is still less than x
# x is currently: 21
# x is still less than x
# x is currently: 22
# x is still less than x
# x is currently: 23
# x is still less than x
# x is currently: 24
# x is still less than x
# x is currently: 25
# x is still less than x
# x is currently: 26
# x is still less than x
# x is currently: 27
# x is still less than x
# x is currently: 28
# x is still less than x
# x is currently: 29
# ...

# %%
a=['apple','banana','cherry','grapes']
while a:
    print(a.pop(-1))
# Out:
# grapes
# cherry
# banana
# apple

# %%
x=8
while i<=10:
    print('x is currently:',x)
    print('x is still less than {}, adding 1 to x'.format(x))
    x+=1
else:
    print('all done!')
# Out:
# x is currently: 8
# x is still less than 8, adding 1 to x
# x is currently: 9
# x is still less than 9, adding 1 to x
# x is currently: 10
# x is still less than 10, adding 1 to x
# x is currently: 11
# x is still less than 11, adding 1 to x
# x is currently: 12
# x is still less than 12, adding 1 to x
# x is currently: 13
# x is still less than 13, adding 1 to x
# x is currently: 14
# x is still less than 14, adding 1 to x
# x is currently: 15
# x is still less than 15, adding 1 to x
# x is currently: 16
# x is still less than 16, adding 1 to x
# x is currently: 17
# x is still less than 17, adding 1 to x
# x is currently: 18
# x is still less than 18, adding 1 to x
# x is currently: 19
# x is still less than 19, adding 1 to x
# x is currently: 20
# x is still less than 20, adding 1 to x
# x is currently: 21
# x is still less than 21, adding 1 to x
# x is currently: 22
# x is still less than 22, adding 1 to x
# x is currently: 23
# x is still less than 23, adding 1 to x
# ...

# %%
x=0

while x<10:
    print('x is currently :',x)
    print('x is still less than {}, add 1 to x'.format(x))
    x+=1
    if x==3:
        print('\nx==3 if condition is true then break it')
        break
    else:
        print('continuing....')
        continue
# Out:
# x is currently : 0
# x is still less than 0, add 1 to x
# continuing....
# x is currently : 1
# x is still less than 1, add 1 to x
# continuing....
# x is currently : 2
# x is still less than 2, add 1 to x
#
# x==3 if condition is true then break it

# %%
x=0

while x<10:
    print('x is currently :',x)
    print('x is still less than {}, add 1 to x'.format(x))
    x+=1
    if x==3:
        print('\nx==3 if condition is true then break it')
        continue
    else:
        print('continuing....')
# Out:
# x is currently : 0
# x is still less than 0, add 1 to x
# continuing....
# x is currently : 1
# x is still less than 1, add 1 to x
# continuing....
# x is currently : 2
# x is still less than 2, add 1 to x
#
# x==3 if condition is true then break it
# x is currently : 3
# x is still less than 3, add 1 to x
# continuing....
# x is currently : 4
# x is still less than 4, add 1 to x
# continuing....
# x is currently : 5
# x is still less than 5, add 1 to x
# continuing....
# x is currently : 6
# x is still less than 6, add 1 to x
# continuing....
# x is currently : 7
# x is still less than 7, add 1 to x
# continuing....
# x is currently : 8
# x is still less than 8, add 1 to x
# continuing....
# x is currently : 9
# x is still less than 9, add 1 to x
# continuing....

# %%
#pattern
i=0
row=5
while i<=rows:
    print("{:^2}".format(chr(98)*i))
    i+=1
# Out:
#
# b
# bb
# bbb
# bbbb
# bbbbb

# %%
#pattern
i=0
row=3
while i<=row:
    print("{:^2}".format(ord('b')*i))
    i+=1
# Out:
# 0
# 98
# 196
# 294
